# %%
import pandas as pd

# Path of the file to read
iowa_file_path = '/Users/duey/CodingProjects/KaggleIntroML/data/train.csv'

# Fill in the line below to read the file into a variable home_data
home_data = pd.read_csv(iowa_file_path)

# Call line below with no argument to check that you've loaded the data correctly
print(home_data.head())

# Print summary statistics in next line
print(home_data.describe())

# What is the average lot size (rounded to nearest integer)?
avg_lot_size = round(home_data['LotArea'].mean()) # mean() function gets average
print(f"Average lot size: {avg_lot_size}")

# As of today, how old is the newest home age (current year - the date in which it was built)?
newest_home_age = 2025 - home_data['YearBuilt'].max() # max() function gets max/highest
print(f"Newest home age: {newest_home_age}")

# %% [markdown]
# # Your newest house in your data isn't that new. a few potential explanations for this:
#     1. They haven't built new houses where this data was collected.
#     2. The data was collected a long time ago. Houses built after the data publication wouldn't show up.
#
# # If the reason is explanation #1 above, does that affect your trust in the model you build with this data? What about if it is reason #2?
#     Personal Answer:
#
#     -If it was reason 1, my trust in the model for that geographic area wouldn't go down because the data is up to date. There are still other factors that come to mind, like why the area hasn't had new houses built in a while. More external factors could also determine the pricing.
#
#     -If it was reason 2 on the other hand, I would question the outcome the mode outputs because it isn't up to date with current housing data in that area. Since the data is outdated, the accuracy of the model would be compromised. Common trends in the existing data may still persist, like how a bigger house with more bedrooms would be more expensive. The objective for the model is to accurately predict current house values, so an up to date set of values must be needed.
#
# # How could you dig into the data to see which explanation is more plausible?
#     Personal Answer:
#
#     -You could check every listing with the newest year built, if it seems like the data got "cut off" at 2010, that could mean the data was collected in 2010.
#
#     -Comparing data to current house listings. You could check if new houses are being listed in this area, if so, then the dataset must by outdated. If no houses are being built past 2010, then the data could still be accurate.
#
#     -If prices seem much lower than today's prices, than that could also be a factor in determining if the data is still relevant.
